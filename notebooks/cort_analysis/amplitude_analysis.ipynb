# %% [markdown]
# # Analysis code for the Precision Medicine grant
#
# * 6/9/2025 setup GT

# %%
import os
import sys
from os.path import join
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns


# from src.classes import database
from notebooks.cort_analysis import metadata 
from src.classes.suite2p_class import Suite2p as s2p
import src.classes.imaging_class as idc

# %%
savedir = "/data2/gergely/invivo_DATA/sleep/summaries/cort_project/"

# %%
mice = metadata.GROUPING
mice

# %%
control_trials
cort_trials

# %%
control_tseries = []
for trial in control_trials:
    control_tseries.append(database.fetch_trial(trial)["tSeries_path"])

cort_tseries[]
for trial in cort_trials:
    cort_tseries.append(database.fetch_trial(trial)["tSeries_path"])
