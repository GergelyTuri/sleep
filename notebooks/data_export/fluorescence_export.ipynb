# %% [markdown]
# # Exporting raw fluorescent data for YP

# %%
import sys
import json
import matplotlib.pyplot as plt
from os.path import join, dirname
import pandas as pd
import numpy as np

sys.path.append("/home/gerit/code/sleep/src")

from classes.suite2p_class import Suite2p as s2p
from classes import behavior_class as bc

# sys.path.append("/")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 11
#       8 sys.path.append("/home/gerit/code/sleep/src")
#      10 from classes.suite2p_class import Suite2p as s2p
# ---> 11 import behavior_class as bc
#      13 # sys.path.append("/")
#
# File ~/code/sleep/src/classes/behavior_class.py:10
#       7 import numpy as np
#       8 import pandas as pd
# ---> 10 from src.classes import imaging_class as ic
#      13 @dataclass
#      14 class BehaviorData:
#      15     """Class for behavior data.
#      16     Initialized with the path to the behavior folder.
#      17     """
#
# ModuleNotFoundError: No module named 'src'
